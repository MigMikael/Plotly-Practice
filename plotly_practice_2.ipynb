# %%
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import pandas as pd
import numpy as np

init_notebook_mode(connected=True)
# print(plotly.__version__)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
title = "MotoCtoiPad Model Varient (Exp. 57-59) (Test By Generated Set)"
filename = 'experiment57-59-GeneratedSet.html'
polyfit_diff = 14.343

hidden_layer = [6, 9, 12, 15, 18, 21, 24, 27, 30, 33]

# %%
# 3 Dense Layer 
x1 = hidden_layer
y1 = [3] * 10
y1 = pd.Series(y1, index=x1)
#print(y1)
z1 = [14.301631931392018, 13.987006292129312, 13.847810354648363, 13.656302416572489, 13.539034995987384, 13.397887932907578, 13.411874858316281, 13.392832373850931, 13.385595140414406, 13.292526862254974]
z1 = pd.Series(z1, index=x1)
print(z1)
# Out:
# 6     14.301632
# 9     13.987006
# 12    13.847810
# 15    13.656302
# 18    13.539035
# 21    13.397888
# 24    13.411875
# 27    13.392832
# 30    13.385595
# 33    13.292527
# dtype: float64

# %%
# 4 Dense Layer
x2 = hidden_layer
y2 = [4] * 10
y2 = pd.Series(y2, index=x2)
#print(y2)
z2 = [14.018928046612848, 13.828498640534395, 13.392071995408555, 13.342755396083907, 13.205639585800085, 13.125587594712421, 12.920704798230563, 12.868688150854105, 12.796183333628923, 12.765420960106093]
z2 = pd.Series(z2, index=x2)
print(z2)
# Out:
# 6     14.018928
# 9     13.828499
# 12    13.392072
# 15    13.342755
# 18    13.205640
# 21    13.125588
# 24    12.920705
# 27    12.868688
# 30    12.796183
# 33    12.765421
# dtype: float64

# %%
# 5 Dense Layer
x3 = hidden_layer
y3 = [5] * 10
y3 = pd.Series(y3, index=x3)
#print(y3)
z3 = [13.799334046603581, 13.505916102614277, 13.311838694154462, 13.14115590224402, 12.978591107502732, 12.738070014302096, 12.75683608200133, 12.627818385809414, 12.608150028557075, 12.448681531664997]
z3 = pd.Series(z3, index=x3)
print(z3)
# Out:
# 6     13.799334
# 9     13.505916
# 12    13.311839
# 15    13.141156
# 18    12.978591
# 21    12.738070
# 24    12.756836
# 27    12.627818
# 30    12.608150
# 33    12.448682
# dtype: float64

# %%
polyfit = polyfit_diff
polyfit_list = [[polyfit_diff] * 30] * 7
#print(polyfit_list)

# %%
trace = go.Scatter3d(
    x=x1, y=y1, z=z1,
    marker=dict(
        size=8,
        color=z1
    ),
    line=dict(
        color='#1f77b4',
        width=2
    )
)

trace2 = go.Scatter3d(
    x=x2, y=y2, z=z2,
    marker=dict(
        size=8,
        color=z2
    ),
    line=dict(
        color='#1f77b4',
        width=2
    )
)

trace3 = go.Scatter3d(
    x=x3, y=y3, z=z3,
    marker=dict(
        size=8,
        color=z3
    ),
    line=dict(
        color='#1f77b4',
        width=2
    )
)

trace4 = go.Surface(
    z=polyfit_list,
    opacity=0.5,
    colorscale='Jet',
    showscale=False
)

data = [trace, trace2, trace3, trace4]
layout = go.Layout(
    width=800,
    height=700,
    title= title,
    scene=dict(
        xaxis=dict(
            title='Hidden Layer Dim (X)',
            titlefont=dict(
                size=14,
                color='#ff0000'
            ),
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(200, 200, 230)'
        ),
        yaxis=dict(
            nticks = 5,
            range = [2, 6],
            title='Dense Layer Num (Y)',
            titlefont=dict(
                size=14,
                color='#ff0000'
            ),
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 200, 230)'
        ),
        zaxis=dict(
            title='Avg Diff (Z)',
            titlefont=dict(
                size=10,
                color='#ff0000'
            ),
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230, 200)'
        ),
    )
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig)
# Out:
# <div id="2d007a3f-006e-4acb-9ee7-f0fcc494ea88" style="height: 700px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2d007a3f-006e-4acb-9ee7-f0fcc494ea88", [{"uid": "56b891f8-dc70-11e8-a7be-001a7dda7111", "type": "scatter3d", "z": [14.301631931392018, 13.987006292129312, 13.847810354648363, 13.656302416572489, 13.539034995987384, 13.397887932907578, 13.411874858316281, 13.392832373850931, 13.385595140414406, 13.292526862254974], "line": {"color": "#1f77b4", "width": 2}, "x": [6, 9, 12, 15, 18, 21, 24, 27, 30, 33], "marker": {"color": [14.301631931392018, 13.987006292129312, 13.847810354648363, 13.656302416572489, 13.539034995987384, 13.397887932907578, 13.411874858316281, 13.392832373850931, 13.385595140414406, 13.292526862254974], "size": 8}, "y": [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]}, {"uid": "56b891f9-dc70-11e8-b3b9-001a7
# ...

# %%
plotly.offline.plot(fig, filename=filename)
# Out:
# 'file://C:\\Users\\Mig\\Documents\\experiment57-59-GeneratedSet.html'
